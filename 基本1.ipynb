# %% [markdown]
# <a href="https://colab.research.google.com/github/elk-william/new/blob/main/%E5%9F%BA%E6%9C%AC1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print(1,2,3)
# Out:
# 1 2 3

# %%
print(1,2,3,sep='*')
# Out:
# 1*2*3

# %%
print(1,2,3,end='!')
print(4,5)
# Out:
# 1 2 3!4 5

# %%
print(input('請輸入文字'))
# Out:
# 請輸入文字妳媽
# 妳媽

# %%
a,b,c=1,2,3
a,b,c=b,a,c
print(a,b,c)
# Out:
# 2 1 3

# %%
a=1
a+=1
a*=2
a/=5.0
print(a)
# Out:
# 0.8

# %% [markdown]
# ```
# 我要記起來的
# ```
# ![截圖 2026-08-01 下午9.45.04.png](data:image/png;base64,...)

# %%
a=float(input('a:'))
b=float(input('b:'))

print(a)
print(b)
print('a+b=',a+b)
print('a-b=',a-b)
print('a*b=',a*b)
print('a/b=',a/b)
# Out:
# a:3
# b:4
# 3.0
# 4.0
# a+b= 7.0
# a-b= -1.0
# a*b= 12.0
# a/b= 0.75

# %%
c=float(input('攝氏溫度C°'))
print('攝氏溫度轉成華氏溫度F°-->',32+(c*9/5))
# Out:
# 攝氏溫度C°25.8
# 攝氏溫度轉成華氏溫度F°--> 78.44
