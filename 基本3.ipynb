# %% [markdown]
# <a href="https://colab.research.google.com/github/elk-william/new/blob/main/%E5%9F%BA%E6%9C%AC3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
i='I have no one.😭'
n='have'
m='me'
a='You %s %s!'%(n,m)
b='You {} {}!'.format(n,m)
c=f'You {n} {m}!'
print(i)
print(a)
print(b)
print(c)
# Out:
# I have no one.😭
# You have me!
# You have me!
# You have me!

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
a=input('name?')
b=input('age?')
print('Hello {}, you are {} years old!'.format(a,b))
# Out:
# name?William
# age?16
# Hello William, you are 16 years old!

# %%
a=3
b=6
c=5
if a>b:
  print('a>b')
else :
  print('a<b')
  if b>c:
    print('b>c')
  else:
    print('b<c')
# Out:
# a<b
# b>c

# %%
a=int(input('請輸入一個數：'))
b=a%3
if b==0:
  print('運勢普通')
elif b==1:
  print('運勢吉')
else :
  print("運勢大吉")
# Out:
# 請輸入一個數：4
# 運勢吉

# %%
a=int(input("請輸入一個數："))
if a%3==0:
  print('普通')
elif a%3==1:
  print('吉')
else:
  print('大吉')
# Out:
# 請輸入一個數：55
# 吉

# %%
a=int(input('請輸入年份：'))
if a%4==0:
  if a%100==0:
    if a%400==0:
      print('閏年')
    else:
      print('平年')
  else:
    print('閏年')
else:
  print('平年')
# Out:
# 請輸入年份：4500
# 平年

# %%
a=int(input('請輸入年份：'))
if ((a%4==0 and a%100!=0) or (a%100==0 and a%400==0)):
  print('閏年')
else:
  print('平年')
# Out:
# 請輸入年份：4888
# 閏年

# %%
for i in 'You are my love!':
  print(i,end='💗')
print('')
for i in ['g','g']:
  print(i,end='')
print('')
for i in range(6):
  for j in range(1,i+1):
    print(i,end='')
  print(i)
print('')
for i in range(1,6):
  for j in range(i):
    print(i,end='')
  print('')

for i in range(5,0,-1):
  for j in range(i):
    print(i,end='')
  print('')
# Out:
# Y💗o💗u💗 💗a💗r💗e💗 💗m💗y💗 💗l💗o💗v💗e💗!💗
# gg
# 0
# 11
# 222
# 3333
# 44444
# 555555
#
# 1
# 22
# 333
# 4444
# 55555
# 55555
# 4444
# 333
# 22
# 1

# %% [markdown]
# ```
# 要呈現這樣子
#    1
#   222
#  33333
#  33333
#   222
#    1
# ```

# %%
#失敗
for i in range(1,4):
  for j in range(2,-1,-1):
    int(j)
  for k in range((2*i)-1):
    print(' '*j+str(i),end='')
  print('')
# Out:
# 1
# 222
# 33333
